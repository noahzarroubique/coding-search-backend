# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('localdata.sqlite')

# %%
import numpy as np
 
def convert_epsg2056_to_epsg4326(x, y):
    """
    Convert coordinates from EPSG:2056 to EPSG:4326.
 
    Args:
        x (float): The x-coordinate in EPSG:2056.
        y (float): The y-coordinate in EPSG:2056.
        z (float): The altitude in EPSG:2056.
 
    Returns:
        tuple: A tuple (lng, lat, alt) in EPSG:4326.
    """
    y_aux, x_aux = (x - 2600000) / 1e6, (y - 1200000) / 1e6
 
    lat = (16.9023892 + 3.238272 * x_aux - 0.270978 * y_aux**2 - 0.002528 * x_aux**2
           - 0.0447 * y_aux**2 * x_aux - 0.0140 * x_aux**3) * 100 / 36
 
    lng = (2.6779094 + 4.728982 * y_aux + 0.791484 * y_aux * x_aux + 0.1306 * y_aux * x_aux**2
           - 0.0436 * y_aux**3) * 100 / 36
  
    return lng, lat

# %%
convert_epsg2056_to_epsg4326(536788,151922 ,406)
# Out:
# (-14.66814349103035, 34.91024106055895, 505.27495712)

# %%
def plz_6_to_4_digits(plz: int) -> int:
    """
    Convert a 6-digit Swiss postal code to a 4-digit one.
 
    Args:
        plz (int): A 6-digit Swiss postal code.
 
    Returns:
        int: The corresponding 4-digit Swiss postal code.
    """
    return plz // 100

# %%
data = pd.read_sql_query("SELECT * FROM plz", conn)
plzs = data.loc[:,["plz_pk", "x", "y", "altitude", "primary_name"]]
plzs[["lon", "lat"]] = plzs.apply(lambda row: convert_epsg2056_to_epsg4326(row["x"]+2000000, row["y"]+1000000), axis=1, result_type="expand")
plzs["plz"] = plzs.apply(lambda row: row["plz_pk"] // 100, axis=1, result_type="expand")
plzs
# Out:
#       plz_pk       x       y  altitude    primary_name       lon        lat  \
# 0     100003  536788  151922       406        Lausanne  6.614940  46.515614
# 1     100025  542061  156539       837        Lausanne  6.683067  46.557622
# 2     100101  538100  152040       448        Lausanne  6.632019  46.516798
# 3     100200  538130  152320       490        Lausanne  6.632372  46.519320
# 4     100300  538100  152444       488        Lausanne  6.631965  46.520432
# ...      ...     ...     ...       ...             ...       ...        ...
# 4266  965200  732830  232722       766  Neu St. Johann  9.192824  47.232061
# 4267  965500  735393  229244       834        Stein SG  9.225614  47.200265
# 4268  965600  739159  228336       887  Alt St. Johann  9.275022  47.191318
# 4269  965700  741833  229135       914     Unterwasser  9.310547  47.197934
# 4270  965800  744583  229640      1047        Wildhaus  9.346990  47.201880
#
#        plz
# 0     1000
# 1     1000
# 2     1001
# 3     1002
# 4     1003
# ...    ...
# 4266  9652
# 4267  9655
# 4268  9656
# 4269  9657
# 4270  9658
#
# [4271 rows x 8 columns]

# %%
data = pd.read_sql_query("SELECT * FROM wetterstation", conn)
wetterstationen = data.loc[:,["name", "x", "y", "altitude", "temperature", "sunshine", "precipitation"]]
wetterstationen[["lon", "lat"]] = wetterstationen.apply(lambda row: convert_epsg2056_to_epsg4326(row["x"]+2000000, row["y"]+1000000), axis=1, result_type="expand")

wetterstationen
# Out:
#                   name       x       y altitude  temperature  sunshine  \
# 0    Villars-Tiercelin  544197  163650    859.0            1         0
# 1                 Visp  631151  128023    639.0            1         1
# 2    La Chaux-de-Fonds  550918  214861   1017.0            1         1
# 3                Scuol  817139  186392   1304.0            1         1
# 4           Teufen, AR  747784  250409    834.0            0         0
# ..                 ...     ...     ...      ...          ...       ...
# 470          Bad Ragaz  756911  209350    497.0            1         1
# 471        Schleitheim  678235  288717    497.0            0         0
# 472         Schmerikon  713726  231532    408.0            0         0
# 473             Glarus  723757  210566    517.0            1         1
# 474        Vicosoprano  768487  135865   1089.0            1         1
#
#      precipitation        lon        lat
# 0                1   6.710060  46.621768
# 1                1   7.842964  46.302890
# 2                1   6.792300  47.082939
# 3                1  10.283267  46.793263
# 4                0   9.396061  47.387921
# ..             ...        ...        ...
# 470              1   9.502592  47.016624
# 471              0   8.481762  47.744351
# 472              0   8.940296  47.224924
# 473              1   9.066967  47.034575
# 474              1   9.627807  46.353013
#
# [475 rows x 9 columns]

# %%
data = pd.read_sql_query("SELECT * FROM poi", conn)
pois = data.loc[:,["primary_name", "x", "y", "altitude", "type_en"]]
pois["type"] = pois["type_en"].map(lambda s: s.upper().replace(" ", "_"))
pois[["lon", "lat"]] = pois.apply(lambda row: convert_epsg2056_to_epsg4326(row["x"]+2000000, row["y"]+1000000), axis=1, result_type="expand")

pois
# Out:
#                       primary_name       x       y  altitude       type_en  \
# 0            Cabane Arpitettaz CAS  618614  105516      2786  Mountain Hut
# 1                Glattalphütte SAC  709410  197202      1898  Mountain Hut
# 2                   Täschhütte SAC  630293  100081      2701  Mountain Hut
# 3                Balmhornhütte SAC  619285  144461      1956  Mountain Hut
# 4            Chamanna Jenatsch CAS  775351  155672      2652  Mountain Hut
# ..                             ...     ...     ...       ...           ...
# 618                  Pizzo Ruscada  689118  114643      2004          Peak
# 619                    Piz Uccello  735107  151369      2724          Peak
# 620  Monte San Giorgio - Mendrisio  717251   85839      1097          Peak
# 621            Rifugio Alpe Masnee  702048  125855      2063  Mountain Hut
# 622                 Poncione Rosso  713480  128602      2506          Peak
#
#              type       lon        lat
# 0    MOUNTAIN_HUT  7.679345  46.100892
# 1    MOUNTAIN_HUT  8.875022  46.916906
# 2    MOUNTAIN_HUT  7.830020  46.051579
# 3    MOUNTAIN_HUT  7.689632  46.451204
# 4    MOUNTAIN_HUT  9.724441  46.529356
# ..            ...       ...        ...
# 618          PEAK  8.592722  46.177357
# 619          PEAK  9.198783  46.499994
# 620          PEAK  8.949784  45.913993
# 621  MOUNTAIN_HUT  8.762586  46.276366
# 622          PEAK  8.911537  46.299241
#
# [623 rows x 8 columns]

# %% [markdown]
# json template
#
# ```json
# {
#     "weatherStations": [
#         {
#             "name": "Zürich",
#             "measurementTypes": [
#                 "temperature",
#                 "sunshine",
#                 "precipitation"
#             ],
#             "location": {
#                 "latitude": 46.6333,
#                 "longitude": 6.7,
#                 "altitude": 800
#             }
#         }
#     ],
#     "pois": [
#         {
#             "name": "Mont Tendre",
#             "type": "PEAK",
#             "location": {
#                 "latitude": 46.6333,
#                 "longitude": 6.7,
#                 "altitude": 800
#             }
#         }
#     ],
#     "plz": [
#         {
#             "name": "Zürich",
#             "plz": "1058",
#             "location": {
#                 "latitude": 46.6333,
#                 "longitude": 6.7,
#                 "altitude": 800
#             }
#         }
#     ]
# }
# ```

# %%
def get_location(row):
    return {"latitude": row["lat"], "longitude": row["lon"], "altitude": row["altitude"]}

# %%
def get_measurement_types(row):
    return {"temperature": row["temperature"]==True, "sunshine": row["sunshine"]==True, "precipitation": row["precipitation"]==True}

# %%
import json

# a json is generated with the data, according to the template

data = {
    "weatherStations": wetterstationen.apply(lambda row: {"name": row["name"], "measurementTypes": get_measurement_types(row), "location": get_location(row)  }, axis=1).tolist(),
    "pois": pois.apply(lambda row: {"name": row["primary_name"], "type": row["type"], "location": get_location(row)  }, axis=1).tolist(),
    "plz": plzs.apply(lambda row: {"name": row["primary_name"], "plz": row["plz"], "location": get_location(row)  }, axis=1).tolist(),
}

with open("data.json", "w") as f:
    json.dump(data, f, ensure_ascii=False)

data["weatherStations"]
# Out:
# [{'name': 'Villars-Tiercelin',
#   'measurementTypes': {'temperature': True,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.62176829438428,
#    'longitude': 6.710059558923346,
#    'altitude': '859.0'}},
#  {'name': 'Visp',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.30288996971511,
#    'longitude': 7.842964018883361,
#    'altitude': '639.0'}},
#  {'name': 'La Chaux-de-Fonds',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.08293932795008,
#    'longitude': 6.792299807369331,
#    'altitude': '1017.0'}},
#  {'name': 'Scuol',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.793262795465694,
#    'longitude': 10.283266666675795,
#    'altitude': '1304.0'}},
#  {'name': 'Teufen, AR',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.38792120747931,
#    'longitude': 9.396060748782167,
#    'altitude': '834.0'}},
#  {'name': 'Escholzmatt',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.90348031543287,
#    'longitude': 7.935400543508521,
#    'altitude': '840.0'}},
#  {'name': 'Col des Mosses',
#   'measurementTypes': {'temperature': True,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.39151886055298,
#    'longitude': 7.098225774335594,
#    'altitude': '1412.0'}},
#  {'name': 'Linthal / Tierfehd',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.8792153330744,
#    'longitude': 8.983706845114863,
#    'altitude': '810.0'}},
#  {'name': 'Kurzeneialp',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.01343262836595,
#    'longitude': 7.840740594543776,
#    'altitude': '894.0'}},
#  {'name': 'Küblis',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.91227530595975,
#    'longitude': 9.777492133931668,
#    'altitude': '839.0'}},
#  {'name': 'Küsnacht, ZH',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.31031486528329,
#    'longitude': 8.585279702415617,
#    'altitude': '413.0'}},
#  {'name': 'Hörnli',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.370850638937206,
#    'longitude': 8.941638666315475,
#    'altitude': '1133.0'}},
#  {'name': 'Splügen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.55260141843711,
#    'longitude': 9.321962170878672,
#    'altitude': '1460.0'}},
#  {'name': 'Hondrich',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.67313674064896,
#    'longitude': 7.680731101495258,
#    'altitude': '760.0'}},
#  {'name': 'Emosson',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.06558621608968,
#    'longitude': 6.930275777159213,
#    'altitude': '1923.0'}},
#  {'name': 'Einsiedeln',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.133028601323154,
#    'longitude': 8.756559180862277,
#    'altitude': '911.0'}},
#  {'name': 'Sierre',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.29876483782213,
#    'longitude': 7.556391539187031,
#    'altitude': '535.0'}},
#  {'name': 'Eigenthal',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.9833301899869,
#    'longitude': 8.218612302684356,
#    'altitude': '1114.0'}},
#  {'name': 'Hoch-Ybrig',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.01175565676999,
#    'longitude': 8.790093419382568,
#    'altitude': '1458.0'}},
#  {'name': 'Sedrun',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.67233970593692,
#    'longitude': 8.745185704712291,
#    'altitude': '1429.0'}},
#  {'name': 'Cevio',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.32047511790964,
#    'longitude': 8.603161834216527,
#    'altitude': '417.0'}},
#  {'name': 'Semsales',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.5759836352687,
#    'longitude': 6.931300086005633,
#    'altitude': '874.0'}},
#  {'name': 'Flims',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.833657621462315,
#    'longitude': 9.283285935348756,
#    'altitude': '1050.0'}},
#  {'name': 'Aarberg',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.05795767531302,
#    'longitude': 7.285349733829597,
#    'altitude': '444.0'}},
#  {'name': 'Sevelen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.12440379052522,
#    'longitude': 9.489530906564166,
#    'altitude': '457.0'}},
#  {'name': "L'Abergement",
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.756171960288384,
#    'longitude': 6.490214574548992,
#    'altitude': '647.0'}},
#  {'name': 'Adelboden',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.49168951944503,
#    'longitude': 7.560705021237098,
#    'altitude': '1321.0'}},
#  {'name': 'Flühli, LU',
#   'measurementTypes': {'temperature': True,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.889425152545016,
#    'longitude': 8.020336318547075,
#    'altitude': '940.0'}},
#  {'name': 'Choëx',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.23212421631418,
#    'longitude': 6.961349290260623,
#    'altitude': '891.0'}},
#  {'name': 'Flawil',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.414135483651165,
#    'longitude': 9.202889660937686,
#    'altitude': '571.0'}},
#  {'name': 'Champéry',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.16272209003294,
#    'longitude': 6.861129723385827,
#    'altitude': '1055.0'}},
#  {'name': 'Göscheneralp',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.64751888097983,
#    'longitude': 8.500018795255976,
#    'altitude': '1745.0'}},
#  {'name': 'Les Diablerets',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.346859382555266,
#    'longitude': 7.16633986750005,
#    'altitude': '1191.0'}},
#  {'name': 'Gösgen',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.36313474840986,
#    'longitude': 7.973729464743665,
#    'altitude': '380.0'}},
#  {'name': 'Vals',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.627747344072446,
#    'longitude': 9.18870837683105,
#    'altitude': '1242.0'}},
#  {'name': 'Les Diablerets',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': False},
#   'location': {'latitude': 46.3267388910074,
#    'longitude': 7.203773306707213,
#    'altitude': '2964.0'}},
#  {'name': 'Thusis',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.709405194848834,
#    'longitude': 9.441714722538753,
#    'altitude': '672.0'}},
#  {'name': 'Thun',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.74984227821403,
#    'longitude': 7.585225439091379,
#    'altitude': '570.0'}},
#  {'name': 'Bernina / Curtinatsch',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.44108736576175,
#    'longitude': 9.986883166415467,
#    'altitude': '2090.0'}},
#  {'name': 'Diessenhofen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.69172248127543,
#    'longitude': 8.727115623871464,
#    'altitude': '404.0'}},
#  {'name': 'Jungfraujoch',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': False},
#   'location': {'latitude': 46.54754500229876,
#    'longitude': 7.985449089272758,
#    'altitude': '3571.0'}},
#  {'name': 'Passo del Bernina',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.40915284995278,
#    'longitude': 10.019563700000042,
#    'altitude': '2260.0'}},
#  {'name': 'Nyon / Changins',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.40104882591434,
#    'longitude': 6.227726902697284,
#    'altitude': '458.0'}},
#  {'name': 'Zugerberg',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.14399925147756,
#    'longitude': 8.533105894449543,
#    'altitude': '927.0'}},
#  {'name': 'Eschlikon',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.452131945635514,
#    'longitude': 8.972871854398086,
#    'altitude': '578.0'}},
#  {'name': 'Jussy',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.22855093368672,
#    'longitude': 6.257903879604395,
#    'altitude': '466.0'}},
#  {'name': 'Göschenen',
#   'measurementTypes': {'temperature': True,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.69267108439295,
#    'longitude': 8.595356695823183,
#    'altitude': '950.0'}},
#  {'name': 'Gornergrat',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': False},
#   'location': {'latitude': 45.98362824524625,
#    'longitude': 7.785737701555188,
#    'altitude': '3129.0'}},
#  {'name': 'Isenthal',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.910595807113104,
#    'longitude': 8.560438992288432,
#    'altitude': '778.0'}},
#  {'name': 'Belp',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.90608551624514,
#    'longitude': 7.5053388494048,
#    'altitude': '510.0'}},
#  {'name': 'Bern / Zollikofen',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.9907379905951,
#    'longitude': 7.464061124365006,
#    'altitude': '553.0'}},
#  {'name': 'Dietikon',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.413550377208985,
#    'longitude': 8.40447358091821,
#    'altitude': '384.0'}},
#  {'name': 'Disentis',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.706558108435594,
#    'longitude': 8.853480423409867,
#    'altitude': '1197.0'}},
#  {'name': 'Tiefencastel',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.66362172068065,
#    'longitude': 9.574461115642386,
#    'altitude': '897.0'}},
#  {'name': 'Stiegelschwand',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.48809929713977,
#    'longitude': 7.533437960974742,
#    'altitude': '1466.0'}},
#  {'name': 'Bex',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.24415465191958,
#    'longitude': 6.995278907861621,
#    'altitude': '402.0'}},
#  {'name': 'Zürich / Affoltern',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.42768537471218,
#    'longitude': 8.51795222523858,
#    'altitude': '444.0'}},
#  {'name': 'Beznau',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.55724394417332,
#    'longitude': 8.233320053275351,
#    'altitude': '326.0'}},
#  {'name': 'Bellelay',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.264508502347425,
#    'longitude': 7.169115631556334,
#    'altitude': '923.0'}},
#  {'name': 'Rempen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.13837095319943,
#    'longitude': 8.896798697099653,
#    'altitude': '650.0'}},
#  {'name': 'Les Charbonnières',
#   'measurementTypes': {'temperature': True,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.67014352724986,
#    'longitude': 6.312433081697378,
#    'altitude': '1045.0'}},
#  {'name': 'Chasseral',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.131752194654524,
#    'longitude': 7.054348836509553,
#    'altitude': '1594.0'}},
#  {'name': 'Chanrion',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 45.93936048389483,
#    'longitude': 7.380591229715776,
#    'altitude': '2473.0'}},
#  {'name': "Château-d'Oex",
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.47981133129426,
#    'longitude': 7.1396542801162655,
#    'altitude': '1028.0'}},
#  {'name': 'Titlis',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': False},
#   'location': {'latitude': 46.77059578363018,
#    'longitude': 8.42597752355608,
#    'altitude': '3045.0'}},
#  {'name': 'Payerne / Ville',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.833395536380834,
#    'longitude': 6.935507747303218,
#    'altitude': '447.0'}},
#  {'name': 'Elm',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.92373084173788,
#    'longitude': 9.17535277673717,
#    'altitude': '958.0'}},
#  {'name': 'Chaumont',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.04916079230898,
#    'longitude': 6.978821419555722,
#    'altitude': '1136.0'}},
#  {'name': 'Payerne',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.811575755495866,
#    'longitude': 6.9424722976549225,
#    'altitude': '490.0'}},
#  {'name': 'Schaffhausen',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.68982786604738,
#    'longitude': 8.620142670275364,
#    'altitude': '438.0'}},
#  {'name': 'Chur',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.87061740622764,
#    'longitude': 9.53081476660294,
#    'altitude': '557.0'}},
#  {'name': 'Cham',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.18826782260775,
#    'longitude': 8.46464248077728,
#    'altitude': '443.0'}},
#  {'name': 'La Fouly',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 45.936614978835586,
#    'longitude': 7.096359989497721,
#    'altitude': '1564.0'}},
#  {'name': 'Chavornay',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.702400087612,
#    'longitude': 6.548002664105635,
#    'altitude': '439.0'}},
#  {'name': 'Salanfe',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.145633868504554,
#    'longitude': 6.972951571187974,
#    'altitude': '1965.0'}},
#  {'name': 'Ulrichen',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.504872714665375,
#    'longitude': 8.308240623136399,
#    'altitude': '1346.0'}},
#  {'name': 'Isérables',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.16091721478641,
#    'longitude': 7.24873600775371,
#    'altitude': '1237.0'}},
#  {'name': 'Oberägeri',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.133625586849874,
#    'longitude': 8.608204151673077,
#    'altitude': '724.0'}},
#  {'name': 'Cimetta',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.20045765614691,
#    'longitude': 8.791656296792432,
#    'altitude': '1661.0'}},
#  {'name': 'Zweisimmen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.55050168140816,
#    'longitude': 7.384917052108092,
#    'altitude': '936.0'}},
#  {'name': 'Segl-Maria',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.4323196518044,
#    'longitude': 9.762325496714766,
#    'altitude': '1804.0'}},
#  {'name': 'Siebnen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.171502862088694,
#    'longitude': 8.900485244033975,
#    'altitude': '452.0'}},
#  {'name': 'Zwillikon',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.29008504045144,
#    'longitude': 8.431960662144554,
#    'altitude': '461.0'}},
#  {'name': 'Sihlbrugg',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.22055485639325,
#    'longitude': 8.578284642889306,
#    'altitude': '549.0'}},
#  {'name': 'Simplon-Dorf',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.196819496385416,
#    'longitude': 8.056341429176506,
#    'altitude': '1465.0'}},
#  {'name': 'Fribourg / Grangeneuve',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.77138724605207,
#    'longitude': 7.113738107089263,
#    'altitude': '651.0'}},
#  {'name': 'Sion',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.218641364815,
#    'longitude': 7.330205448135512,
#    'altitude': '482.0'}},
#  {'name': 'Grächen',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.19530520297813,
#    'longitude': 7.8368159598198055,
#    'altitude': '1605.0'}},
#  {'name': 'Grenchen',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.179092889920604,
#    'longitude': 7.415129033130987,
#    'altitude': '428.0'}},
#  {'name': 'Grimsel Hospiz',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.57168216533416,
#    'longitude': 8.333251402534938,
#    'altitude': '1980.0'}},
#  {'name': 'Sissach',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.464372109838465,
#    'longitude': 7.803363058477158,
#    'altitude': '380.0'}},
#  {'name': 'Engelberg',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.82162829790022,
#    'longitude': 8.410517994329455,
#    'altitude': '1036.0'}},
#  {'name': 'Grimentz',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.179980379634465,
#    'longitude': 7.578085738439103,
#    'altitude': '1512.0'}},
#  {'name': 'Visperterminen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.26287551112758,
#    'longitude': 7.904210288713699,
#    'altitude': '1352.0'}},
#  {'name': 'Andelfingen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.6046597352306,
#    'longitude': 8.67028876714631,
#    'altitude': '360.0'}},
#  {'name': 'Grono',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.25506240196807,
#    'longitude': 9.16376245032827,
#    'altitude': '324.0'}},
#  {'name': 'Entlebuch',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.98680617369124,
#    'longitude': 8.068753254761704,
#    'altitude': '768.0'}},
#  {'name': 'Herbetswil',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.2967024546361,
#    'longitude': 7.587929697006509,
#    'altitude': '544.0'}},
#  {'name': 'Affeltrangen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.53715967346539,
#    'longitude': 9.01570843793109,
#    'altitude': '541.0'}},
#  {'name': 'Gryon',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.27693947158335,
#    'longitude': 7.069155387560382,
#    'altitude': '1146.0'}},
#  {'name': 'Obstalden',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.11387991892721,
#    'longitude': 9.163398144975131,
#    'altitude': '689.0'}},
#  {'name': 'Yverdon-les-Bains',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.781889934801384,
#    'longitude': 6.650995653254267,
#    'altitude': '432.0'}},
#  {'name': 'Unterkulm',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.319808950339045,
#    'longitude': 8.111083116505357,
#    'altitude': '454.0'}},
#  {'name': 'Col du Grand St-Bernard',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 45.869081873093364,
#    'longitude': 7.1706692839781345,
#    'altitude': '2472.0'}},
#  {'name': 'Oberiberg',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.03737657941069,
#    'longitude': 8.778658807736011,
#    'altitude': '1075.0'}},
#  {'name': 'Les Ponts-de-Martel',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.99751186258433,
#    'longitude': 6.727180887601115,
#    'altitude': '1052.0'}},
#  {'name': 'Dischma',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.77193519708328,
#    'longitude': 9.882080517692371,
#    'altitude': '1710.0'}},
#  {'name': 'Gsteig, Gstaad',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.37652518959155,
#    'longitude': 7.278590638821939,
#    'altitude': '1196.0'}},
#  {'name': 'Biasca',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.33604397386179,
#    'longitude': 8.978197616696031,
#    'altitude': '278.0'}},
#  {'name': 'Unterschächen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.871313479678776,
#    'longitude': 8.775283797350854,
#    'altitude': '1470.0'}},
#  {'name': 'Oberriet / Kriessern',
#   'measurementTypes': {'temperature': True,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.37659688645905,
#    'longitude': 9.61270384292293,
#    'altitude': '409.0'}},
#  {'name': 'Bière',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.524899949050074,
#    'longitude': 6.342381764866941,
#    'altitude': '684.0'}},
#  {'name': 'Binn',
#   'measurementTypes': {'temperature': True,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.367647464079774,
#    'longitude': 8.192305873273654,
#    'altitude': '1479.0'}},
#  {'name': 'Gross, SZ',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.112732247687305,
#    'longitude': 8.779977290963641,
#    'altitude': '897.0'}},
#  {'name': 'Huttwil',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.11399189990832,
#    'longitude': 7.837357905640529,
#    'altitude': '633.0'}},
#  {'name': 'Les Bioux',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.61621455888603,
#    'longitude': 6.26131899699145,
#    'altitude': '1025.0'}},
#  {'name': 'Findelen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.01095189515243,
#    'longitude': 7.778384316289295,
#    'altitude': '2170.0'}},
#  {'name': 'Bisisthal',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.9438224751998,
#    'longitude': 8.830723202181916,
#    'altitude': '856.0'}},
#  {'name': 'Ricken',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.26262016482632,
#    'longitude': 9.059686440850772,
#    'altitude': '836.0'}},
#  {'name': 'Bivio',
#   'measurementTypes': {'temperature': True,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.46248456785317,
#    'longitude': 9.668642270521902,
#    'altitude': '1856.0'}},
#  {'name': 'Riehen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.57425407371039,
#    'longitude': 7.623768879620796,
#    'altitude': '260.0'}},
#  {'name': 'Bischofszell / Sitterdorf',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.50882017064414,
#    'longitude': 9.266802611101276,
#    'altitude': '507.0'}},
#  {'name': 'Fräschels',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.996450573709055,
#    'longitude': 7.205932149915338,
#    'altitude': '454.0'}},
#  {'name': 'Baltschiedertal',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.34230862705808,
#    'longitude': 7.879327993534192,
#    'altitude': '1318.0'}},
#  {'name': 'Fruence',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.52521468621895,
#    'longitude': 6.9025945484156725,
#    'altitude': '812.0'}},
#  {'name': 'Stallikon',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.30463585999095,
#    'longitude': 8.50101067175054,
#    'altitude': '754.0'}},
#  {'name': 'Derborence',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.288491367397434,
#    'longitude': 7.232498868672952,
#    'altitude': '1366.0'}},
#  {'name': 'Bullet / La Frétaz',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.840616277093474,
#    'longitude': 6.576367492054579,
#    'altitude': '1205.0'}},
#  {'name': 'Frauenfeld',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.573099887975395,
#    'longitude': 8.893699682705941,
#    'altitude': '393.0'}},
#  {'name': 'Frick',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.51361347691399,
#    'longitude': 8.014179606670451,
#    'altitude': '345.0'}},
#  {'name': 'Napf',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.004657796646285,
#    'longitude': 7.940110598641297,
#    'altitude': '1404.0'}},
#  {'name': 'Naluns / Schlivera',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': False},
#   'location': {'latitude': 46.8171548058006,
#    'longitude': 10.261400596964078,
#    'altitude': '2380.0'}},
#  {'name': 'Guttannen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.656438378315045,
#    'longitude': 8.291722415712503,
#    'altitude': '1055.0'}},
#  {'name': 'Eptingen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.38589204674497,
#    'longitude': 7.818983190082171,
#    'altitude': '565.0'}},
#  {'name': 'Frutigen',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.59899705741269,
#    'longitude': 7.657534614095869,
#    'altitude': '756.0'}},
#  {'name': 'Pfäffikon, ZH',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.37680893831331,
#    'longitude': 8.754865284336889,
#    'altitude': '537.0'}},
#  {'name': 'Vrin',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.655783951704954,
#    'longitude': 9.103476951660292,
#    'altitude': '1384.0'}},
#  {'name': 'Anzère',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.305235667529516,
#    'longitude': 7.407575885701139,
#    'altitude': '1614.0'}},
#  {'name': 'Crap Masegn',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': False},
#   'location': {'latitude': 46.84226803691506,
#    'longitude': 9.180040885917691,
#    'altitude': '2468.0'}},
#  {'name': 'Benken / Doggen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.188726294829074,
#    'longitude': 8.961213042441974,
#    'altitude': '408.0'}},
#  {'name': 'Gütsch, Andermatt',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.652466095694045,
#    'longitude': 8.615530394519526,
#    'altitude': '2286.0'}},
#  {'name': 'Guglera',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.74973254798608,
#    'longitude': 7.242855036177032,
#    'altitude': '877.0'}},
#  {'name': 'Camedo',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.155289411939975,
#    'longitude': 8.60750549121257,
#    'altitude': '590.0'}},
#  {'name': 'Affoltern i. E.',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.06311401389078,
#    'longitude': 7.740608690734463,
#    'altitude': '755.0'}},
#  {'name': 'Aigle',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.32663426386911,
#    'longitude': 6.924472131805824,
#    'altitude': '381.0'}},
#  {'name': 'La Dôle',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.4247892477231,
#    'longitude': 6.099448569954169,
#    'altitude': '1670.0'}},
#  {'name': 'Zürich / Fluntern',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.37791813075891,
#    'longitude': 8.565743890796092,
#    'altitude': '556.0'}},
#  {'name': 'Güttingen',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.601722238090304,
#    'longitude': 9.279432395568765,
#    'altitude': '440.0'}},
#  {'name': 'Airolo',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.52613291448246,
#    'longitude': 8.597443302424441,
#    'altitude': '1139.0'}},
#  {'name': 'Morges',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.516603343657295,
#    'longitude': 6.5109463217296275,
#    'altitude': '374.0'}},
#  {'name': 'Martigny',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.10977834371836,
#    'longitude': 7.0625134534053196,
#    'altitude': '461.0'}},
#  {'name': 'Ehrendingen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.508117204017935,
#    'longitude': 8.339047391769748,
#    'altitude': '428.0'}},
#  {'name': 'Tsanfleuron',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.32069268995098,
#    'longitude': 7.301788208360991,
#    'altitude': '2052.0'}},
#  {'name': 'Madiswil',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.16037586030666,
#    'longitude': 7.797309801124424,
#    'altitude': '542.0'}},
#  {'name': 'Magadino / Cadenazzo',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.160016296601974,
#    'longitude': 8.933671126470005,
#    'altitude': '203.0'}},
#  {'name': 'Sta. Maria, Val Müstair',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.6022488032544,
#    'longitude': 10.426309457462995,
#    'altitude': '1386.0'}},
#  {'name': 'Erlenbach im Simmental',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.65847414774833,
#    'longitude': 7.524042678317812,
#    'altitude': '732.0'}},
#  {'name': 'Mathod',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.73697320990444,
#    'longitude': 6.567988050362124,
#    'altitude': '435.0'}},
#  {'name': 'Blatten, Lötschental',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.42044298735442,
#    'longitude': 7.823196320540649,
#    'altitude': '1538.0'}},
#  {'name': 'La Valsainte',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.647756601571395,
#    'longitude': 7.178565601339162,
#    'altitude': '1044.0'}},
#  {'name': 'Genève / Cointrin',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.247512575574845,
#    'longitude': 6.1277361087657765,
#    'altitude': '411.0'}},
#  {'name': 'Malbun',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.10314955652088,
#    'longitude': 9.608613135403818,
#    'altitude': '1610.0'}},
#  {'name': 'Eriswil',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.08341638889383,
#    'longitude': 7.850483549754691,
#    'altitude': '729.0'}},
#  {'name': 'Marsens',
#   'measurementTypes': {'temperature': True,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.656478712799455,
#    'longitude': 7.069669780024886,
#    'altitude': '715.0'}},
#  {'name': 'Les Marécottes',
#   'measurementTypes': {'temperature': True,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.118890446039195,
#    'longitude': 7.016592806969534,
#    'altitude': '990.0'}},
#  {'name': 'Martina',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.88400052375886,
#    'longitude': 10.463030113390394,
#    'altitude': '1041.0'}},
#  {'name': 'Urnerboden',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.8988092498734,
#    'longitude': 8.917065870815474,
#    'altitude': '1395.0'}},
#  {'name': 'Brülisau',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.29412775769479,
#    'longitude': 9.460068214389796,
#    'altitude': '928.0'}},
#  {'name': 'Blumenstein',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.744248838834224,
#    'longitude': 7.520553723377781,
#    'altitude': '655.0'}},
#  {'name': 'Trient',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.04630169652827,
#    'longitude': 6.994661624564298,
#    'altitude': '1329.0'}},
#  {'name': 'Marbach, LU',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.857311090926686,
#    'longitude': 7.902151595953999,
#    'altitude': '864.0'}},
#  {'name': 'Seengen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.32731970088205,
#    'longitude': 8.188449712425127,
#    'altitude': '445.0'}},
#  {'name': 'Chanéaz',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.7292850401797,
#    'longitude': 6.742845010031706,
#    'altitude': '758.0'}},
#  {'name': 'Grindelwald',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.6297244744243,
#    'longitude': 8.03678990302149,
#    'altitude': '1152.0'}},
#  {'name': 'Urnäsch',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.31201872733262,
#    'longitude': 9.279797908314928,
#    'altitude': '825.0'}},
#  {'name': 'Bellinzona',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.18987594861194,
#    'longitude': 9.004874506050788,
#    'altitude': '224.0'}},
#  {'name': 'Stans',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.969190823277145,
#    'longitude': 8.345548796019294,
#    'altitude': '439.0'}},
#  {'name': 'Combe-Garot',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.96233262724445,
#    'longitude': 6.79771867473842,
#    'altitude': '532.0'}},
#  {'name': 'Acquarossa / Comprovasco',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.45950981647793,
#    'longitude': 8.935485148291397,
#    'altitude': '575.0'}},
#  {'name': 'Coldrerio',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 45.85390860626578,
#    'longitude': 8.997428681966484,
#    'altitude': '347.0'}},
#  {'name': 'Les Collons',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.17896632522856,
#    'longitude': 7.387355125322532,
#    'altitude': '1770.0'}},
#  {'name': 'Courtepin',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.86007597093327,
#    'longitude': 7.127575746904504,
#    'altitude': '565.0'}},
#  {'name': 'Cossonay',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.60951330299881,
#    'longitude': 6.493087105925466,
#    'altitude': '590.0'}},
#  {'name': 'Couvet',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.93353053670512,
#    'longitude': 6.658688699213841,
#    'altitude': '728.0'}},
#  {'name': 'Nesselboden',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.24515808631509,
#    'longitude': 7.5085753288891794,
#    'altitude': '1055.0'}},
#  {'name': 'Soglio',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.342556540224706,
#    'longitude': 9.535533734799644,
#    'altitude': '1088.0'}},
#  {'name': 'Beromünster',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.20730187731124,
#    'longitude': 8.193631216228308,
#    'altitude': '642.0'}},
#  {'name': 'Piz Corvatsch',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.41802832812018,
#    'longitude': 9.821311243044702,
#    'altitude': '3294.0'}},
#  {'name': 'Courtelary',
#   'measurementTypes': {'temperature': True,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.18080004141799,
#    'longitude': 7.090645688097595,
#    'altitude': '695.0'}},
#  {'name': 'Langenbruck',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.352874029445175,
#    'longitude': 7.759586774217502,
#    'altitude': '731.0'}},
#  {'name': 'Eschenz',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.64569383615713,
#    'longitude': 8.873914496518058,
#    'altitude': '414.0'}},
#  {'name': 'Lachen / Galgenen',
#   'measurementTypes': {'temperature': True,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.17918732146166,
#    'longitude': 8.858684295885176,
#    'altitude': '468.0'}},
#  {'name': 'Pigniu',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.81028952047733,
#    'longitude': 9.115133557648896,
#    'altitude': '1325.0'}},
#  {'name': 'Laufen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.41395259472096,
#    'longitude': 7.5267773106200515,
#    'altitude': '404.0'}},
#  {'name': 'Lägern',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': False},
#   'location': {'latitude': 47.481925830223695,
#    'longitude': 8.397222741822846,
#    'altitude': '845.0'}},
#  {'name': 'Pilatus',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.97885945998374,
#    'longitude': 8.25226058724018,
#    'altitude': '2105.0'}},
#  {'name': 'Langnau i.E.',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.93962471847351,
#    'longitude': 7.8064224576896795,
#    'altitude': '744.0'}},
#  {'name': 'Sonogno',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.34958655569141,
#    'longitude': 8.788224083267302,
#    'altitude': '910.0'}},
#  {'name': 'Piotta',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.51480011848571,
#    'longitude': 8.688045413214786,
#    'altitude': '990.0'}},
#  {'name': 'Uster',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.35073790478531,
#    'longitude': 8.692792023025973,
#    'altitude': '438.0'}},
#  {'name': 'Les Brenets',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.071959712794055,
#    'longitude': 6.710222420061937,
#    'altitude': '908.0'}},
#  {'name': 'Landquart',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.96452053045595,
#    'longitude': 9.576417966618827,
#    'altitude': '537.0'}},
#  {'name': 'Nendaz',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.12208152576963,
#    'longitude': 7.3114064085453645,
#    'altitude': '1938.0'}},
#  {'name': 'Laupen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.916754831739965,
#    'longitude': 7.240474729785496,
#    'altitude': '483.0'}},
#  {'name': 'Sorniot-Lac Inférieur',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.16658671123555,
#    'longitude': 7.0997980920932555,
#    'altitude': '1990.0'}},
#  {'name': 'Bergün / Latsch',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.62726330590286,
#    'longitude': 9.753705295313347,
#    'altitude': '1408.0'}},
#  {'name': 'Neuchâtel',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.00005857927714,
#    'longitude': 6.953287183787288,
#    'altitude': '485.0'}},
#  {'name': 'Mattsand',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.143434709410336,
#    'longitude': 7.791283746086222,
#    'altitude': '1230.0'}},
#  {'name': 'Altmatt',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.13103108863976,
#    'longitude': 8.696347166494506,
#    'altitude': '920.0'}},
#  {'name': 'Alpnach',
#   'measurementTypes': {'temperature': True,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.93623122274635,
#    'longitude': 8.281808525664744,
#    'altitude': '445.0'}},
#  {'name': 'Sempach',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.13532671290083,
#    'longitude': 8.195688026647709,
#    'altitude': '532.0'}},
#  {'name': 'Altstätten, SG',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.38321926205235,
#    'longitude': 9.556525023820273,
#    'altitude': '430.0'}},
#  {'name': 'Braunau',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.52228199758091,
#    'longitude': 9.073381170302742,
#    'altitude': '592.0'}},
#  {'name': 'Schüpfheim',
#   'measurementTypes': {'temperature': True,
# ...
#    'altitude': '1641.0'}},
#  {'name': 'Campocologno',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.23784625389676,
#    'longitude': 10.135241890792283,
#    'altitude': '577.0'}},
#  {'name': 'Mülligen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.45595729767367,
#    'longitude': 8.241317083840656,
#    'altitude': '367.0'}},
#  {'name': 'Lausanne',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.527807666300525,
#    'longitude': 6.6432729358517255,
#    'altitude': '601.0'}},
#  {'name': 'Giswil',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.84943935638493,
#    'longitude': 8.190225905096911,
#    'altitude': '471.0'}},
#  {'name': 'Zernez',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.69786375454607,
#    'longitude': 10.08960882617594,
#    'altitude': '1470.0'}},
#  {'name': 'Jona',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.223900178771196,
#    'longitude': 8.848290976269734,
#    'altitude': '410.0'}},
#  {'name': 'Müstair',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.63541799239476,
#    'longitude': 10.45850522275568,
#    'altitude': '1248.0'}},
#  {'name': 'Stetten',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.39649435528903,
#    'longitude': 8.299991832133387,
#    'altitude': '355.0'}},
#  {'name': 'Muri, AG',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.26537229721312,
#    'longitude': 8.327610158849417,
#    'altitude': '577.0'}},
#  {'name': 'Grüningen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.27350289805908,
#    'longitude': 8.743741718972814,
#    'altitude': '535.0'}},
#  {'name': 'Murten',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.94211923815832,
#    'longitude': 7.136439218494057,
#    'altitude': '433.0'}},
#  {'name': 'Zofingen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.28018810086468,
#    'longitude': 7.943384480458988,
#    'altitude': '432.0'}},
#  {'name': 'Wasen im Emmental',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.04539480383933,
#    'longitude': 7.8051210099259976,
#    'altitude': '770.0'}},
#  {'name': 'Uetliberg',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': False},
#   'location': {'latitude': 47.351356886648944,
#    'longitude': 8.490227347706245,
#    'altitude': '854.0'}},
#  {'name': 'Widnau',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.36944398034577,
#    'longitude': 9.643060101013967,
#    'altitude': '411.0'}},
#  {'name': 'Sangernboden',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.716312824129325,
#    'longitude': 7.349962070178943,
#    'altitude': '1035.0'}},
#  {'name': 'Säntis',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.24943502559479,
#    'longitude': 9.34346989392477,
#    'altitude': '2501.0'}},
#  {'name': 'Sattel, SZ',
#   'measurementTypes': {'temperature': True,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.08105385621964,
#    'longitude': 8.636964942204575,
#    'altitude': '790.0'}},
#  {'name': 'Cavaglia',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.36787103472653,
#    'longitude': 10.03634850718544,
#    'altitude': '1707.0'}},
#  {'name': 'Saignelégier',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.25689880656738,
#    'longitude': 6.980838954862992,
#    'altitude': '883.0'}},
#  {'name': 'Lauterbrunnen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.592911956007505,
#    'longitude': 7.906463102790692,
#    'altitude': '815.0'}},
#  {'name': 'Montana',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.298796900852,
#    'longitude': 7.460817556948673,
#    'altitude': '1423.0'}},
#  {'name': 'Winterthur / Seen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.47466506059224,
#    'longitude': 8.76318934420072,
#    'altitude': '506.0'}},
#  {'name': 'Samedan',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.52623990071484,
#    'longitude': 9.879471867518433,
#    'altitude': '1709.0'}},
#  {'name': 'Innerferrera',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.52023425040421,
#    'longitude': 9.444021673795492,
#    'altitude': '1475.0'}},
#  {'name': 'Wimmis',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.670778642419435,
#    'longitude': 7.663784455253964,
#    'altitude': '648.0'}},
#  {'name': 'St. Antönien',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.972120452427504,
#    'longitude': 9.825919070407192,
#    'altitude': '1456.0'}},
#  {'name': 'Otemma',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 45.924362135610984,
#    'longitude': 7.3932133911121065,
#    'altitude': '2357.0'}},
#  {'name': 'Safien Platz',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.678698041767134,
#    'longitude': 9.315079570998451,
#    'altitude': '1296.0'}},
#  {'name': 'Wittnau',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.48039104802129,
#    'longitude': 7.968539980006536,
#    'altitude': '463.0'}},
#  {'name': 'Effretikon',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.43881397887886,
#    'longitude': 8.7025028560817,
#    'altitude': '478.0'}},
#  {'name': 'Sargans',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.053851962360454,
#    'longitude': 9.439974277465192,
#    'altitude': '590.0'}},
#  {'name': 'Innerthal',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.10643139950294,
#    'longitude': 8.915285649518564,
#    'altitude': '903.0'}},
#  {'name': 'Hallau',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.69726973613373,
#    'longitude': 8.470471250131514,
#    'altitude': '419.0'}},
#  {'name': 'Kronberg',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.29149754244204,
#    'longitude': 9.327581598296215,
#    'altitude': '1645.0'}},
#  {'name': 'Salez / Saxerriet',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.23295368827446,
#    'longitude': 9.493090499841733,
#    'altitude': '436.0'}},
#  {'name': 'Interlaken',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.6722262476765,
#    'longitude': 7.870192357735086,
#    'altitude': '577.0'}},
#  {'name': 'Saas Balen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.15995975328625,
#    'longitude': 7.924549900739074,
#    'altitude': '1461.0'}},
#  {'name': 'Châbles',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.8259870501131,
#    'longitude': 6.81571039379088,
#    'altitude': '589.0'}},
#  {'name': 'Tour de Gourze',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.51033107632251,
#    'longitude': 6.740953202962631,
#    'altitude': '915.0'}},
#  {'name': 'S. Bernardino',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.46353581563233,
#    'longitude': 9.184694851437785,
#    'altitude': '1639.0'}},
#  {'name': 'Barrage Grande Dixence',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.08371892169848,
#    'longitude': 7.403138458390466,
#    'altitude': '2162.0'}},
#  {'name': 'Lugano',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.00420781549257,
#    'longitude': 8.960319921365512,
#    'altitude': '273.0'}},
#  {'name': 'Stabio',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 45.84343889109372,
#    'longitude': 8.932366953303363,
#    'altitude': '351.0'}},
#  {'name': 'Lungern',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.785073489521196,
#    'longitude': 8.162507419660505,
#    'altitude': '740.0'}},
#  {'name': 'Degersheim',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.36589376979685,
#    'longitude': 9.194182376170088,
#    'altitude': '830.0'}},
#  {'name': 'Eggishorn',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': False},
#   'location': {'latitude': 46.42652331858665,
#    'longitude': 8.092728508173117,
#    'altitude': '2892.0'}},
#  {'name': 'Filisur',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.67086642395932,
#    'longitude': 9.689894984169856,
#    'altitude': '1030.0'}},
#  {'name': 'Moiry',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.137710777070716,
#    'longitude': 7.570200636006733,
#    'altitude': '2127.0'}},
#  {'name': 'Luthern',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.058199463941456,
#    'longitude': 7.918603381782622,
#    'altitude': '767.0'}},
#  {'name': 'Lachen / Eggen',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.43394021683875,
#    'longitude': 9.586655156771325,
#    'altitude': '930.0'}},
#  {'name': 'Egolzwil',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.179421303839575,
#    'longitude': 8.00475522134361,
#    'altitude': '522.0'}},
#  {'name': 'Delémont',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.351693587423235,
#    'longitude': 7.349554430083718,
#    'altitude': '439.0'}},
#  {'name': 'Fionnay',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.03134139226357,
#    'longitude': 7.308957023786271,
#    'altitude': '1500.0'}},
#  {'name': 'Bauma',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.3645676087906,
#    'longitude': 8.905553515610352,
#    'altitude': '667.0'}},
#  {'name': 'Bantiger',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': False},
#   'location': {'latitude': 46.97779743610395,
#    'longitude': 7.5286640128654465,
#    'altitude': '942.0'}},
#  {'name': 'Fieschertal',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 46.42789897545859,
#    'longitude': 8.141024785333487,
#    'altitude': '1175.0'}},
#  {'name': 'Luzern',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.03643508228065,
#    'longitude': 8.301027841173878,
#    'altitude': '454.0'}},
#  {'name': 'Schänis',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.170299106392015,
#    'longitude': 9.020741242733726,
#    'altitude': '415.0'}},
#  {'name': 'Eggersriet',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.43874842472004,
#    'longitude': 9.467907724701263,
#    'altitude': '770.0'}},
#  {'name': 'Basel / Binningen',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.54113341763296,
#    'longitude': 7.583529017064289,
#    'altitude': '316.0'}},
#  {'name': 'Schwarzenegg',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.80554383769308,
#    'longitude': 7.722750233418212,
#    'altitude': '902.0'}},
#  {'name': 'Balsthal',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.32035357995815,
#    'longitude': 7.716628271163973,
#    'altitude': '523.0'}},
#  {'name': 'Scudellate',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 45.9217236432855,
#    'longitude': 9.039348244398184,
#    'altitude': '918.0'}},
#  {'name': 'Baulmes',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 46.789478682745326,
#    'longitude': 6.5225820386625575,
#    'altitude': '642.0'}},
#  {'name': 'Barmelweid',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': True},
#   'location': {'latitude': 47.4214472567559,
#    'longitude': 7.969491150966846,
#    'altitude': '777.0'}},
#  {'name': 'Bad Ragaz',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.016624317737104,
#    'longitude': 9.502592349625484,
#    'altitude': '497.0'}},
#  {'name': 'Schleitheim',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.74435125660832,
#    'longitude': 8.481762109882899,
#    'altitude': '497.0'}},
#  {'name': 'Schmerikon',
#   'measurementTypes': {'temperature': False,
#    'sunshine': False,
#    'precipitation': False},
#   'location': {'latitude': 47.224923579792794,
#    'longitude': 8.940295866296319,
#    'altitude': '408.0'}},
#  {'name': 'Glarus',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 47.03457501679732,
#    'longitude': 9.066967072891186,
#    'altitude': '517.0'}},
#  {'name': 'Vicosoprano',
#   'measurementTypes': {'temperature': True,
#    'sunshine': True,
#    'precipitation': True},
#   'location': {'latitude': 46.35301337628462,
#    'longitude': 9.627807374551587,
#    'altitude': '1089.0'}}]
